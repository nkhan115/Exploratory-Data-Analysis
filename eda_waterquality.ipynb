# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt 
import seaborn as sb 
import random 

random.seed(1)
water = pd.read_csv('/Users/nasif/Desktop/datasets/waterQuality1.csv')
water.head()
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
# ...

# %%
#file dimensions
print("Dimensions of water quality dataset: " + str(water.shape))
# Out:
# Dimensions of water quality dataset: (1000, 21)

# %%
#count null values if any
water.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
#find max values for each element
water.max()
# Out:
# aluminium       5.000
# ammonia        29.840
# arsenic         0.050
# barium          4.000
# cadmium         0.009
# chloramine      7.990
# chromium        0.900
# copper          2.000
# flouride        1.500
# bacteria        1.000
# viruses         1.000
# lead            0.200
# nitrates       18.990
# nitrites        2.000
# mercury         0.010
# perchlorate    59.740
# radium          7.990
# selenium        0.100
# silver          0.500
# uranium         0.090
# is_safe         1.000
# dtype: float64

# %%
#lets try to look for where lead is highest
water.loc[water['lead'] == water['lead'].max()]
# Out:
#      aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 417       3.68    14.03     0.02    2.62    0.004        6.64      0.59
# 738       4.39    18.91     0.04    0.73    0.003        2.92      0.41
#
#      copper  flouride  bacteria  ...  lead  nitrates  nitrites  mercury  \
# 417    1.54      0.64      0.26  ...   0.2     14.45      1.87    0.003
# 738    1.26      1.04      0.17  ...   0.2     16.09      1.23    0.005
#
#      perchlorate  radium  selenium  silver  uranium  is_safe
# 417        58.63    4.76      0.09    0.06     0.04        0
# 738         4.79    4.52      0.06    0.45     0.05        1
#
# [2 rows x 21 columns]

# %%
'''now we know that there are two locations where lead is at its highest, however, only one of the two is
considered safe. let's further this analysis by exploring the one that is not safe'''

#the second highest element in this location is ammonia. let's compare ammonia and lead to see if they have any kind of (inverse) relationship
sb.lmplot(x= 'lead', y= 'ammonia', data=water)

# %%
'''there is not a strong relationship between ammonia and lead.
